# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series from list

# %%
# string

country = ['Bd', 'India', 'Nepal', 'Finland']
pd.Series(country)
# Out:
# 0         Bd
# 1      India
# 2      Nepal
# 3    Finland
# dtype: object

# %%
# integers

runs = pd.Series([90, 23, 54, 11, 48, 87])
runs
# Out:
# 0    90
# 1    23
# 2    54
# 3    11
# 4    48
# 5    87
# dtype: int64

# %%
# Custom index -> index

marks = [87, 98, 79, 91, 75]
sub = ['P', 'S', 'W', 'X', 'J']

pd.Series(marks, index = sub)
# Out:
# [87, 98, 79, 91, 75]

# %%
# Set own object type -> name

marks = [87, 98, 79, 91, 75]
sub = ['P', 'S', 'W', 'X', 'J']

pd.Series(marks, index = sub)
pd.Series(marks, index = sub, name = "Student marks")
# Out:
# P    87
# S    98
# W    79
# X    91
# J    75
# Name: Student marks, dtype: int64

# %% [markdown]
# ### Series from dict

# %%
marks = {
    'p' : 83,
    's' : 89,
    'x' : 71,
    'k' : 94
}

pd.Series(marks, name = "your mark")
# Out:
# p    83
# s    89
# x    71
# k    94
# Name: your mark, dtype: int64

# %% [markdown]
# ### Series attribute

# %%
# Size -> how many values are in series

marks = {
    'p' : 83,
    's' : 89,
    'x' : 71,
    'k' : 94
}

mark_series = pd.Series(marks, name = "your mark")
mark_series.size
 
# dtype
mark_series.dtype

# name 
mark_series.name

# is_unique (False if item repeat)
mark_series.is_unique
pd.Series([1, 2, 1, 3, 4, 2, 4, 5]).is_unique

# index (return all index)
mark_series.index

# values
mark_series.values
# Out:
# array([83, 89, 71, 94], dtype=int64)

# %% [markdown]
# ### Series using read_csv

# %%
# Squeeze -> convert dataframe to series

subs_data = pd.read_csv('./subs.csv')
subs_data.head(365)
type(pd.read_csv('./subs.csv')) # this is dataframe
type(pd.read_csv('./subs.csv').squeeze()) # this is series
subs = subs_data.squeeze(True)
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# index_col -> which col became index

kohli_data = pd.read_csv('./kohli_ipl.csv', index_col = 'match_no')
vk = kohli_data.squeeze(True)
type(vk)
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movie_data = pd.read_csv('./bollywood.csv', index_col = 'movie')
movie = movie_data.squeeze()
movie
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series Method

# %%
# head -> preview of data from first
subs_data.head() # by default 5 data
vk.head(10)

# tail -> preview of data from last
vk.tail()
vk.tail(10)
# Out:
# match_no
# 206     0
# 207     0
# 208     9
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# Sample -> random 1 row
movie.sample() 
movie.sample(6)
# Out:
# movie
# Kalank                           Varun Dhawan
# 99 (2009 film)                    Kunal Khemu
# Blackmail (2005 film)              Ajay Devgn
# Saaho                    Jacqueline Fernandez
# Xcuse Me                        Sharman Joshi
# Helicopter Eela                         Kajol
# Name: lead, dtype: object

# %%
# value_counts -> return frequency of item in data

movie.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values 

vk.sort_values(ascending = False).head(1).values[0] # descending (method chaining)
vk.sort_values() # ascending
vk.sort_values(ascending = False) # descending
# vk.sort_values(inplace = True) # temporary change not change in original
# Out:
# match_no
# 128    113
# 126    109
# 123    108
# 164    100
# 120    100
#       ...
# 93       0
# 211      0
# 130      0
# 8        0
# 135      0
# Name: runs, Length: 215, dtype: int64

# %%
# sort_index

movie.sort_index()
# movie.sort_index(inplace = True) # permanent sort
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series Math Methods

# %%
# count (total number of item present in series)-> not count missing value but size dose

vk.count()
# Out:
# 215

# %%
# Sum / Product -> of all values

subs.sum()
subs.product()
# Out:
# 0

# %%
# Statistical method

# mean (avg)
subs.mean()

# median (middle value)
vk.median()

# mode (appear most)
movie.mode()

# std (standard deviation)
subs.std()

# var (variance)
vk.var()
# Out:
# 688.0024777222343

# %%
# min / max -> value 

subs.min()
subs.max()
# Out:
# 396

# %%
# Describe -> give summary of multiple(math) thing 

vk.describe()
subs.describe()
movie.describe()
# Out:
# count             1500
# unique             566
# top       Akshay Kumar
# freq                48
# Name: lead, dtype: object

# %% [markdown]
# ### Series Indexing

# %%
# Positive indexing 

x = pd.Series([9, 8, 7, 6, 5, 4, 3, 2, 1])
x[0]
x[1:5]
x[1:5:2]

# Negative indexing not work here
# print(movie
movie[0]
movie['Uri: The Surgical Strike']
movie[-1]
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_18148\3685663971.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movie[0]
# C:\Users\Asus\AppData\Local\Temp\ipykernel_18148\3685663971.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   movie[-1]
# 'Akshay Kumar'

# %%
# Slicing 

vk
vk[5:16]
vk[-5:]
movie[-5:]

# Fancy indexing

vk[[1, 7, 3, 2, 5]]
# Out:
# match_no
# 1     1
# 7    34
# 3    13
# 2    23
# 5     1
# Name: runs, dtype: int64

# %% [markdown]
# ### Editing in series

# %%
mark_series[1] = 100 # change using index
mark_series['k'] = 100
mark_series

# without using index
mark_series['aa'] = 79
mark_series

# slicing
runs[2:4] = [123, 69]
runs

# Fancy indexing
runs[[0, 3, 5]] = [0, 0, 0]
runs

movie['Aankhen (2002 film)'] = "Coca Cola"
movie
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_18148\554651880.py:1: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   mark_series[1] = 100 # change using index
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                            Coca Cola
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ### Series with python function

# %%
print(len(subs))
print(type(movie))
print(dir(subs))
print(sorted(subs)) # output in list
print(max(subs))
print(min(subs))

# type conversion
list(mark_series)
dict(mark_series)

# membership operator (run in index)
movie
'Why Cheat India' in movie # only search in index
'Emraan Hashmi' in movie.values # search in value

# looping (run in value)
for  i in movie:
    i
for i in movie.index: # search in index
    i

# arithmetic operator (Broadcasting)
100 - mark_series
5 + mark_series

# relational operator
vk >= 50
vk[vk >= 50]
# Out:
# 365
# <class 'pandas.core.series.Series'>
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__bool__', '__class__', '__column_consortium_standard__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__', '__rmod__', '__rmul__', '__ror__', '__round__', '__rpow__', '__rsub__', '__rtruediv__', '__rxor__', '__setattr__', '__setitem__', '__setstate__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__truediv__', '__weakref__', '__xor__', '_accessors', '_accum_func', '_agg_examples_doc', '_agg_see_also_doc', '_align_for_op', '_align_frame', '_align_series', '_append', '_arith_method', '_as_manager', '_attrs', '_binop', '_cacher', '_can_hold_na', '_check_inplace_and_allows_duplicate_labels', '_check_is_chained_assignment_possible', '_check_label_or_level_ambiguity', '_check_setitem_copy', '_clear_item_cache', '_clip_with_one_bound', '_clip_with_scalar', '_cmp_method', '_consolidate', '_consolidate_inplace', '_construct_axes_dict', '_construct_result', '_constructor', '_constructor_expanddim', '_constructor_expanddim_from_mgr', '_constructor_from_mgr', '_data', '_deprecate_downcast', '_dir_additions', '_dir_deletions', '_drop_axis', '_drop_labels_or_levels', '_duplicated', '_expanddim_from_mgr', '_find_valid_index', '_flags', '_flex_method', '_from_mgr', '_get_axis', '_get_axis_name', '_get_axis_number', '_get_axis_resolvers', '_get_block_manager_axis', '_get_bool_data', '_get_cacher', '_get_cleaned_column_resolvers', '_get_index_resolvers', '_get_label_or_level_values', '_get_numeric_data', '_get_rows_with_mask', '_get_value', '_get_values_tuple', '_get_with', '_getitem_slice', '_gotitem', '_hidden_attrs', '_indexed_same', '_info_axis', '_info_axis_name', '_info_axis_number', '_init_dict', '_init_mgr', '_inplace_method', '_internal_names', '_internal_names_set', '_is_cached', '_is_copy', '_is_label_or_level_reference', '_is_label_reference', '_is_level_reference', '_is_mixed_type', '_is_view', '_is_view_after_cow_rules', '_item_cache', '_ixs', '_logical_func', '_logical_method', '_map_values', '_maybe_update_cacher', '_memory_usage', '_metadata', '_mgr', '_min_count_stat_function', '_name', '_needs_reindex_multi', '_pad_or_backfill', '_protect_consolidate', '_reduce', '_references', '_reindex_axes', '_reindex_indexer', '_reindex_multi', '_reindex_with_indexers', '_rename', '_replace_single', '_repr_data_resource_', '_repr_latex_', '_reset_cache', '_reset_cacher', '_set_as_cached', '_set_axis', '_set_axis_name', '_set_axis_nocheck', '_set_is_copy', '_set_labels', '_set_name', '_set_value', '_set_values', '_set_with', '_set_with_engine', '_shift_with_freq', '_slice', '_stat_function', '_stat_function_ddof', '_take_with_is_copy', '_to_latex_via_styler', '_typ', '_update_inplace', '_validate_dtype', '_values', '_where', 'abs', 'add', 'add_prefix', 'add_suffix', 'agg', 'aggregate', 'align', 'all', 'any', 'apply', 'argmax', 'argmin', 'argsort', 'array', 'asfreq', 'asof', 'astype', 'at', 'at_time', 'attrs', 'autocorr', 'axes', 'backfill', 'between', 'between_time', 'bfill', 'bool', 'case_when', 'clip', 'combine', 'combine_first', 'compare', 'convert_dtypes', 'copy', 'corr', 'count', 'cov', 'cummax', 'cummin', 'cumprod', 'cum ...
# [33, 33, 35, 37, 39, 40, 40, 40, 40, 42, 42, 43, 44, 44, 44, 45, 46, 46, 48, 49, 49, 49, 49, 50, 50, 50, 51, 54, 56, 56, 56, 56, 57, 61, 62, 64, 65, 65, 66, 66, 66, 66, 67, 68, 70, 70, 70, 71, 71, 72, 72, 72, 72, 72, 73, 74, 74, 75, 76, 76, 76, 76, 77, 77, 78, 78, 78, 79, 79, 80, 80, 80, 81, 81, 82, 82, 83, 83, 83, 84, 84, 84, 85, 86, 86, 86, 87, 87, 87, 87, 88, 88, 88, 88, 88, 89, 89, 89, 90, 90, 90, 90, 91, 92, 92, 92, 93, 93, 93, 93, 95, 95, 96, 96, 96, 96, 97, 97, 98, 98, 99, 99, 100, 100, 100, 101, 101, 101, 102, 102, 103, 103, 104, 104, 104, 105, 105, 105, 105, 105, 105, 105, 105, 105, 108, 108, 108, 108, 108, 108, 109, 109, 110, 110, 110, 111, 111, 112, 113, 113, 113, 114, 114, 114, 114, 115, 115, 115, 115, 117, 117, 117, 118, 118, 119, 119, 119, 119, 120, 122, 123, 123, 123, 123, 123, 124, 125, 126, 127, 128, 128, 129, 130, 131, 131, 132, 132, 134, 134, 134, 135, 135, 136, 136, 136, 137, 138, 138, 138, 139, 140, 144, 145, 146, 146, 146, 146, 147, 149, 150, 150, 150, 150, 151, 152, 152, 152, 153, 153, 153, 154, 154, 154, 155, 155, 156, 156, 156, 156, 157, 157, 157, 157, 158, 158, 159, 159, 160, 160, 160, 160, 162, 164, 166, 167, 167, 168, 170, 170, 170, 170, 171, 172, 172, 173, 173, 173, 174, 174, 175, 175, 176, 176, 177, 178, 179, 179, 180, 180, 180, 182, 183, 183, 183, 184, 184, 184, 185, 185, 185, 185, 186, 186, 186, 188, 189, 190, 190, 192, 192, 192, 196, 196, 196, 197, 197, 202, 202, 202, 203, 204, 206, 207, 209, 210, 210, 211, 212, 213, 214, 216, 219, 220, 221, 221, 222, 222, 224, 225, 225, 226, 227, 228, 229, 230, 231, 233, 236, 236, 237, 241, 243, 244, 245, 247, 249, 254, 254, 258, 259, 259, 261, 261, 265, 267, 268, 269, 276, 276, 290, 295, 301, 306, 312, 396]
# 396
# 33
# match_no
# 15      50
# 34      58
# 41      71
# 44      56
# 45      67
# 52      70
# 57      57
# 68      73
# 71      51
# 73      58
# 74      65
# 80      57
# 81      93
# 82      99
# 85      56
# 97      67
# 99      73
# 103     51
# 104     62
# 110     82
# 116     75
# 117     79
# 119     80
# 120    100
# 122     52
# 123    108
# 126    109
# 127     75
# 128    113
# 129     54
# 131     54
# 132     62
# 134     64
# 137     55
# 141     58
# 144     57
# 145     92
# 148     68
# 152     70
# 160     84
# 162     67
# 164    100
# 175     72
# 178     90
# 182     50
# 188     72
# 197     51
# 198     53
# 209     58
# 213     73
# Name: runs, dtype: int64

# %%
# Boolean indexing on series

vk[vk >= 50]
vk[vk >= 100]
vk[vk >= 100].size
vk[vk == 0]

subs[subs > 200].size

# find actor who done more than 20 movie
num_of_movie = movie.value_counts() 
num_of_movie > 20
num_of_movie[num_of_movie > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    44
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# ### Plotting graph on series

# %%
subs.plot() # convert it into 2d
# Out:
# <Axes: >

# %%
vk.plot()
# Out:
# <Axes: xlabel='match_no'>

# %%
movie.value_counts()
movie.value_counts().head(25)
movie.value_counts().head(25).plot(kind = 'bar')
# Out:
# <Axes: xlabel='lead'>

# %%
movie.value_counts().head(25).plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>
